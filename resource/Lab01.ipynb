# %%
# !lscpu

# %%
# !clinfo

# %%
# !nvidia-smi

# %%
# %%writefile hello.cpp
#
# #include <iostream>
#
# int main() {
#   std::cout << "hello world" << std::endl;
#   return 0;
# }

# %%
# %%script bash
#
# g++ hello.cpp -std=c++11
# ./a.out
